# %%
import ultralytics
from IPython.display import display, Image

# %% [markdown]
# ## Custom Training

# %%
model = ultralytics.YOLO("yolov8n.pt")

# %%
results = model.train(data="dataset/blender/data.yaml", epochs=3, )  # train the model
metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.0.40 🚀 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24214MiB)
# ...

# %% [markdown]
# ## Validate Custom Model

# %%
# results = model.val()

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml

# %% [markdown]
# ## Inference with Custom Model

# %%
model.predict(conf=0.7, source="render.mp4", save=True)
# Out:
# Ultralytics YOLOv8.0.40 🚀 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24214MiB)
#
# video 1/1 (1/558) /home/vladushked/Documents/yolov8/render.mp4: 384x640 1 triangle, 1 Target circle, 7.4ms
# video 1/1 (2/558) /home/vladushked/Documents/yolov8/render.mp4: 384x640 1 triangle, 1 Target circle, 6.0ms
# video 1/1 (3/558) /home/vladushked/Documents/yolov8/render.mp4: 384x640 1 triangle, 1 Target circle, 6.0ms
# video 1/1 (4/558) /home/vladushked/Documents/yolov8/render.mp4: 384x640 1 triangle, 1 Target circle, 5.5ms
# video 1/1 (5/558) /home/vladushked/Documents/yolov8/render.mp4: 384x640 1 triangle, 1 Target circle, 5.4ms
# video 1/1 (6/558) /home/vladushked/Documents/yolov8/render.mp4: 384x640 1 triangle, 1 Target circle, 5.8ms
# video 1/1 (7/558) /home/vladushked/Documents/yolov8/render.mp4: 384x640 1 triangle, 1 Target circle, 5.5ms
# video 1/1 (8/558) /home/vladushked/Documents/yolov8/render.mp4: 384x640 1 triangle, 1 Target circle, 5.4ms
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.7 source={dataset.location}/test/images

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg'):
      display(Image(filename=image_path, width=600))
      print("\n")
